# %% [markdown]
# <a href="https://colab.research.google.com/github/SruthiGS-Gito/Assessment_1/blob/main/SruthiGS_intermediate_assessment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intermediate Python Assessment
#
# Welcome to the assessment!
# This notebook contains 3 challenges. Please read the instructions carefully and complete each task in the provided code cells.
#
#
# **Rules:**
# - Do not change function names or signatures.
# - Write clean, well-documented code.
# - Run all cells before submission.

# %% [markdown]
# ## Challenge 1: Word Frequency Analyzer
# Write a function `top_k_words(filename: str, k: int) -> list` that returns the top k frequent words.
# - Ignore case and punctuation.
# - Sort by frequency, then alphabetically.

# %%
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
  with open("sample.txt", "r") as f:
    text = f.read()
    text = text.lower()

  for char in ".":
        text = text.replace(char, "") # To replace special characters, in this case full stop only

  words = text.split() # split() : To remove whitespaces
  freq = {} # To store frequency of word in dictionary format : Holding key value pairs

  for word in words:
    if word in freq:
      freq[word] += 1
    else:
      freq[word] = 1

    sorted_words = sorted() # Not sort() it's sorted()
  return sorted_words[:k]

# Sample Test (create a sample file)
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7044/1989560188.py in <cell line: 0>()
#      28     f.write("Data science is evolving. Python is versatile. Learning never stops.")
#      29
# ---> 30 print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
#
# /tmp/ipykernel_7044/1989560188.py in top_k_words(filename, k)
#      19       freq[word] = 1
#      20
# ---> 21     sorted_words = sorted() # Not sort() it's sorted()
#      22   return sorted_words[:k]
#      23
#
# TypeError: sorted expected 1 argument, got 0

# %% [markdown]
# ## Challenge 2 : Analyze daily expenses and extract insights.
# User enters:
#
# Number of transactions
# Category and amount
#
# Food 200
# Travel 500
# Food 300
# Shopping 700
#
# ### Output
# * Total expense
# * Highest expense category
# * Category-wise total

# %%
def analyze_expenses():
    n = int(input("Enter number of transactions: "))
    expenses = {}

    for _ in range(n):
      category, amount = input().split()
      amount = float(amount)
      if category in expenses:
        expenses[category] += amount
      else:
        expenses[category] = amount
        # TODO: store category-wise total


    total = sum(expenses.values()) # sum() : To take sum of all amounts in expenses dictionary
    highest_category = max(expenses.keys()) # max() to find the maximum

    # TODO: calculate total expense
    # TODO: find highest category

    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)

analyze_expenses()

# %% [markdown]
# ### Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)
#
# 10 ,20 ,abc ,30 ,-5 , 40
#
# * Remove invalid values
# * Remove negative values
#
#
# Show:
# * Clean list
# * Average
# * Max value

# %%
def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input()

        try:
            num = float(value)

            # TODO: ignore negative values

            data.append(num)

        except:
            # TODO: handle invalid values
            pass

    # TODO: calculate average
    # TODO: find max

    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)

clean_data()
